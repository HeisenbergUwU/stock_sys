# %%
from core.tendency_service import *
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./2025-09-24/sh.000001_上证综合指数_pred.csv")

# %%
data["close"]
# Out:
# 0      3704.0854
# 1      3636.1453
# 2      3625.4897
# 3      3575.9937
# 4      3634.8286
#          ...
# 175    3137.9844
# 176    3136.7007
# 177    3148.0247
# 178    3185.7786
# 179    3158.8599
# Name: close, Length: 180, dtype: float64

# %%
rolling_trend(data["close"])
# Out:
# [(0, -26.461996216826645, 0.9173733310431493),
#  (5, -14.267618351214006, 0.8162152266514296),
#  (10, -3.62745697346133, 0.25120715390414095),
#  (15, 2.364197967250136, 0.33973975087867725),
#  (20, 3.5830001129305384, 0.5253786057829446),
#  (25, 0.061838848108425264, 0.0002056343756884349),
#  (30, -4.398590852625631, 0.5305313898367774),
#  (35, -8.130464088085828, 0.7980382644235025),
#  (40, -6.588607848673069, 0.6345662447751079),
#  (45, -0.28225657820440925, 0.0021686406280621018),
#  (50, 8.460384528514961, 0.7116978083795851),
#  (55, 5.389801242236026, 0.27073009014747274),
#  (60, -5.999882608695652, 0.207105601135385),
#  (65, -13.423685601355164, 0.6816793669737655),
#  (70, -9.730669734613207, 0.47948321913668834),
#  (75, -8.125821061547143, 0.4278007718648016),
#  (80, -10.376496442687738, 0.5527029672962116),
#  (85, -9.023164709203838, 0.43785984268125533),
#  (90, -8.388210784867315, 0.42424908343990975),
#  (95, -11.41675522303783, 0.5428994308174891),
# ...

# %%
is_bloom_ascent(data["close"])
# Out:
# False
